# %%
import pandas as pd

# %%
import json
with open('songs_by_alphabet.json', 'r') as f:
    data = json.load(f)
songs = pd.DataFrame(data)

# %%
songs.to_json("edited.json")

# %%
songs[songs.title=="Thisara Vile [Rosa Wasanthe Sinhala Film].mp3"]
# Out:
#       added_date               artist downloads listens lyrics  \
# 5068  2011-08-10  Samitha Mudunkotuwa    38,197   2,459   None
#
#                                    mobile_download_path  \
# 5068  http://www.ananmanan.lk/free-sinhala-mp3/downl...
#
#                   mp3_download_path music  \
# 5068  ../../downloadzip.php?id=1933    \n
#
#                                      online_listen_path  \
# 5068  http://www.ananmanan.lk/free-sinhala-mp3/sinha...
#
#                                               song_page  \
# 5068  http://www.ananmanan.lk/free-sinhala-mp3/song/...
#
#                                               title  \
# 5068  Thisara Vile [Rosa Wasanthe Sinhala Film].mp3
#
#                                       zip_download_path
# 5068  http://www.ananmanan.lk/free-sinhala-mp3/liste...

# %%
import numpy as np
songs.downloads = songs.downloads.str.replace(",","")

# %%
songs.listens = songs.listens.str.replace(",","")

# %%
songs[songs.lyrics.].lyrics = ""
# Out:
# /home/gayan/.local/lib/python3.6/site-packages/pandas/core/generic.py:4405: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
songs
# Out:
#       added_date                         artist downloads listens  \
# 0     2009-03-01              Sunil Edirisinghe    124304    7710
# 1     2013-02-11                     Funky Dirt    162560    5423
# 2     2009-03-01            Chamara Weerasinghe     87816    4937
# 3     2011-08-14                Anuradha Perera      6163    1346
# 4     2015-08-04               Amarasiri Peiris     13714     978
# 5     2012-08-13                   Sanka Dineth     14505    2398
# 6     2016-06-21                Kasun Chamikara     62207    1901
# 7     2014-06-09              Chathuri Lakshika      7047     624
# 8     2015-06-01                Gayani Madhusha     10556     932
# 9     2015-07-09             Asanka Priyamantha    157763    2790
# 10    2011-09-27                    Shan Hassim    101870    4027
# 11    2009-04-05                   C T Fernando     39523    3693
# 12    2009-03-01  Charitha Priyadarshani Peiris     44830    2808
# ...

# %%
songs.to_json("edited.json",orient="records")
